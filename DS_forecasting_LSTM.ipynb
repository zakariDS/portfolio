# %%
# packages
#!pip install tensorflow
import numpy
import pandas as pd
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return numpy.array(dataX), numpy.array(dataY)

# fix random seed for reproducibility
numpy.random.seed(7)

# load the dataset
dataframe = pd.read_csv('fpmtti6.csv', usecols=[1], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')

# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# split into train and test sets
train_size = int(len(dataset) * 0.8)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]


# reshape into X=t and Y=t+1
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# reshape input to be [samples, time steps, features]
trainX = numpy.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = numpy.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)

# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))

# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# Epoch 1/100
# 55/55 - 1s - loss: 0.2722 - 1s/epoch - 21ms/step
# Epoch 2/100
# 55/55 - 0s - loss: 0.1892 - 61ms/epoch - 1ms/step
# Epoch 3/100
# 55/55 - 0s - loss: 0.1192 - 58ms/epoch - 1ms/step
# Epoch 4/100
# 55/55 - 0s - loss: 0.0696 - 60ms/epoch - 1ms/step
# Epoch 5/100
# 55/55 - 0s - loss: 0.0414 - 57ms/epoch - 1ms/step
# Epoch 6/100
# 55/55 - 0s - loss: 0.0304 - 66ms/epoch - 1ms/step
# Epoch 7/100
# 55/55 - 0s - loss: 0.0279 - 60ms/epoch - 1ms/step
# Epoch 8/100
# 55/55 - 0s - loss: 0.0268 - 61ms/epoch - 1ms/step
# Epoch 9/100
# 55/55 - 0s - loss: 0.0267 - 62ms/epoch - 1ms/step
# Epoch 10/100
# 55/55 - 0s - loss: 0.0264 - 59ms/epoch - 1ms/step
# Epoch 11/100
# 55/55 - 0s - loss: 0.0265 - 63ms/epoch - 1ms/step
# Epoch 12/100
# 55/55 - 0s - loss: 0.0260 - 60ms/epoch - 1ms/step
# Epoch 13/100
# 55/55 - 0s - loss: 0.0262 - 65ms/epoch - 1ms/step
# Epoch 14/100
# 55/55 - 0s - loss: 0.0259 - 61ms/epoch - 1ms/step
# Epoch 15/100
# 55/55 - 0s - loss: 0.0259 - 56ms/epoch - 1ms/step
# Epoch 16/100
# 55/55 - 0s - loss: 0.0257 - 67ms/epoch - 1ms/step
# Epoch 17/100
# 55/55 - 0s - loss: 0.0254 - 58ms/epoch - 1ms/step
# Epoch 18/100
# 55/55 - 0s - loss: 0.0255 - 63ms/epoch - 1ms/step
# Epoch 19/100
# 55/55 - 0s - loss: 0.0253 - 66ms/epoch - 1ms/step
# Epoch 20/100
# 55/55 - 0s - loss: 0.0254 - 66ms/epoch - 1ms/step
# Epoch 21/100
# 55/55 - 0s - loss: 0.0251 - 68ms/epoch - 1ms/step
# Epoch 22/100
# 55/55 - 0s - loss: 0.0252 - 59ms/epoch - 1ms/step
# Epoch 23/100
# 55/55 - 0s - loss: 0.0250 - 59ms/epoch - 1ms/step
# Epoch 24/100
# 55/55 - 0s - loss: 0.0247 - 57ms/epoch - 1ms/step
# Epoch 25/100
# 55/55 - 0s - loss: 0.0246 - 66ms/epoch - 1ms/step
# Epoch 26/100
# 55/55 - 0s - loss: 0.0248 - 57ms/epoch - 1ms/step
# Epoch 27/100
# 55/55 - 0s - loss: 0.0245 - 59ms/epoch - 1ms/step
# Epoch 28/100
# 55/55 - 0s - loss: 0.0244 - 59ms/epoch - 1ms/step
# Epoch 29/100
# 55/55 - 0s - loss: 0.0243 - 60ms/epoch - 1ms/step
# Epoch 30/100
# 55/55 - 0s - loss: 0.0243 - 65ms/epoch - 1ms/step
# Epoch 31/100
# 55/55 - 0s - loss: 0.0243 - 60ms/epoch - 1ms/step
# Epoch 32/100
# 55/55 - 0s - loss: 0.0241 - 61ms/epoch - 1ms/step
# Epoch 33/100
# 55/55 - 0s - loss: 0.0242 - 57ms/epoch - 1ms/step
# Epoch 34/100
# 55/55 - 0s - loss: 0.0241 - 61ms/epoch - 1ms/step
# Epoch 35/100
# 55/55 - 0s - loss: 0.0239 - 65ms/epoch - 1ms/step
# Epoch 36/100
# 55/55 - 0s - loss: 0.0240 - 59ms/epoch - 1ms/step
# Epoch 37/100
# 55/55 - 0s - loss: 0.0239 - 58ms/epoch - 1ms/step
# Epoch 38/100
# 55/55 - 0s - loss: 0.0238 - 61ms/epoch - 1ms/step
# Epoch 39/100
# 55/55 - 0s - loss: 0.0237 - 57ms/epoch - 1ms/step
# Epoch 40/100
# 55/55 - 0s - loss: 0.0237 - 60ms/epoch - 1ms/step
# Epoch 41/100
# 55/55 - 0s - loss: 0.0243 - 59ms/epoch - 1ms/step
# Epoch 42/100
# 55/55 - 0s - loss: 0.0237 - 61ms/epoch - 1ms/step
# Epoch 43/100
# 55/55 - 0s - loss: 0.0236 - 62ms/epoch - 1ms/step
# Epoch 44/100
# 55/55 - 0s - loss: 0.0235 - 69ms/epoch - 1ms/step
# Epoch 45/100
# 55/55 - 0s - loss: 0.0239 - 63ms/epoch - 1ms/step
# Epoch 46/100
# 55/55 - 0s - loss: 0.0236 - 60ms/epoch - 1ms/step
# Epoch 47/100
# 55/55 - 0s - loss: 0.0234 - 62ms/epoch - 1ms/step
# Epoch 48/100
# 55/55 - 0s - loss: 0.0235 - 53ms/epoch - 961us/step
# Epoch 49/100
# 55/55 - 0s - loss: 0.0236 - 62ms/epoch - 1ms/step
# Epoch 50/100
# 55/55 - 0s - loss: 0.0236 - 62ms/epoch - 1ms/step
# Epoch 51/100
# 55/55 - 0s - loss: 0.0240 - 62ms/epoch - 1ms/step
# Epoch 52/100
# 55/55 - 0s - loss: 0.0233 - 55ms/epoch - 997us/step
# Epoch 53/100
# 55/55 - 0s - loss: 0.0235 - 63ms/epoch - 1ms/step
# Epoch 54/100
# 55/55 - 0s - loss: 0.0234 - 60ms/epoch - 1ms/step
# Epoch 55/100
# 55/55 - 0s - loss: 0.0233 - 57ms/epoch - 1ms/step
# Epoch 56/100
# 55/55 - 0s - loss: 0.0231 - 54ms/epoch - 979us/step
# Epoch 57/100
# 55/55 - 0s - loss: 0.0233 - 58ms/epoch - 1ms/step
# Epoch 58/100
# 55/55 - 0s - loss: 0.0231 - 59ms/epoch - 1ms/step
# Epoch 59/100
# 55/55 - 0s - loss: 0.0234 - 54ms/epoch - 988us/step
# Epoch 60/100
# 55/55 - 0s - loss: 0.0232 - 57ms/epoch - 1ms/step
# Epoch 61/100
# 55/55 - 0s - loss: 0.0231 - 60ms/epoch - 1ms/step
# Epoch 62/100
# 55/55 - 0s - loss: 0.0232 - 59ms/epoch - 1ms/step
# Epoch 63/100
# 55/55 - 0s - loss: 0.0230 - 59ms/epoch - 1ms/step
# Epoch 64/100
# 55/55 - 0s - loss: 0.0231 - 56ms/epoch - 1ms/step
# Epoch 65/100
# 55/55 - 0s - loss: 0.0230 - 56ms/epoch - 1ms/step
# Epoch 66/100
# 55/55 - 0s - loss: 0.0231 - 57ms/epoch - 1ms/step
# Epoch 67/100
# 55/55 - 0s - loss: 0.0232 - 58ms/epoch - 1ms/step
# Epoch 68/100
# 55/55 - 0s - loss: 0.0236 - 56ms/epoch - 1ms/step
# Epoch 69/100
# 55/55 - 0s - loss: 0.0231 - 64ms/epoch - 1ms/step
# Epoch 70/100
# 55/55 - 0s - loss: 0.0229 - 59ms/epoch - 1ms/step
# Epoch 71/100
# 55/55 - 0s - loss: 0.0231 - 54ms/epoch - 980us/step
# Epoch 72/100
# 55/55 - 0s - loss: 0.0230 - 65ms/epoch - 1ms/step
# Epoch 73/100
# 55/55 - 0s - loss: 0.0232 - 59ms/epoch - 1ms/step
# Epoch 74/100
# 55/55 - 0s - loss: 0.0233 - 53ms/epoch - 961us/step
# Epoch 75/100
# 55/55 - 0s - loss: 0.0229 - 54ms/epoch - 979us/step
# Epoch 76/100
# 55/55 - 0s - loss: 0.0229 - 60ms/epoch - 1ms/step
# Epoch 77/100
# 55/55 - 0s - loss: 0.0229 - 59ms/epoch - 1ms/step
# Epoch 78/100
# 55/55 - 0s - loss: 0.0229 - 57ms/epoch - 1ms/step
# Epoch 79/100
# 55/55 - 0s - loss: 0.0232 - 58ms/epoch - 1ms/step
# Epoch 80/100
# 55/55 - 0s - loss: 0.0230 - 60ms/epoch - 1ms/step
# Epoch 81/100
# 55/55 - 0s - loss: 0.0230 - 56ms/epoch - 1ms/step
# Epoch 82/100
# 55/55 - 0s - loss: 0.0229 - 57ms/epoch - 1ms/step
# Epoch 83/100
# 55/55 - 0s - loss: 0.0232 - 65ms/epoch - 1ms/step
# Epoch 84/100
# 55/55 - 0s - loss: 0.0233 - 59ms/epoch - 1ms/step
# Epoch 85/100
# 55/55 - 0s - loss: 0.0229 - 63ms/epoch - 1ms/step
# Epoch 86/100
# 55/55 - 0s - loss: 0.0231 - 57ms/epoch - 1ms/step
# Epoch 87/100
# 55/55 - 0s - loss: 0.0229 - 57ms/epoch - 1ms/step
# Epoch 88/100
# 55/55 - 0s - loss: 0.0231 - 59ms/epoch - 1ms/step
# Epoch 89/100
# 55/55 - 0s - loss: 0.0231 - 56ms/epoch - 1ms/step
# Epoch 90/100
# 55/55 - 0s - loss: 0.0230 - 57ms/epoch - 1ms/step
# Epoch 91/100
# 55/55 - 0s - loss: 0.0230 - 60ms/epoch - 1ms/step
# Epoch 92/100
# 55/55 - 0s - loss: 0.0230 - 61ms/epoch - 1ms/step
# Epoch 93/100
# 55/55 - 0s - loss: 0.0230 - 57ms/epoch - 1ms/step
# Epoch 94/100
# 55/55 - 0s - loss: 0.0228 - 54ms/epoch - 991us/step
# Epoch 95/100
# 55/55 - 0s - loss: 0.0233 - 62ms/epoch - 1ms/step
# Epoch 96/100
# 55/55 - 0s - loss: 0.0228 - 57ms/epoch - 1ms/step
# Epoch 97/100
# 55/55 - 0s - loss: 0.0230 - 66ms/epoch - 1ms/step
# Epoch 98/100
# 55/55 - 0s - loss: 0.0229 - 59ms/epoch - 1ms/step
# Epoch 99/100
# 55/55 - 0s - loss: 0.0233 - 57ms/epoch - 1ms/step
# Epoch 100/100
# 55/55 - 0s - loss: 0.0233 - 55ms/epoch - 997us/step
# Train Score: 0.02 RMSE
# Test Score: 0.03 RMSE
